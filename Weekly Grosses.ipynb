# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1.5)

# %% [markdown]
# # The Data

# %%
df = pd.read_excel('Broadway_Grosses.xlsx')

# %%
df.head()
# Out:
#         date  show  type theatre  previews  performances  grosses  \
# 0 2017-05-21  1984  Play  Hudson         4             0   212626
# 1 2017-05-28  1984  Play  Hudson         7             0   298438
# 2 2017-06-04  1984  Play  Hudson         8             0   282053
# 3 2017-06-11  1984  Play  Hudson         8             0   288446
# 4 2017-06-18  1984  Play  Hudson         8             0   301461
#
#   prev_week_gross  GG%GP  attend  prev_week_attend  %cap  close_month  \
# 0               $   0.48    3378               NaN  0.87            0
# 1          212626   0.45    5079            3378.0  0.75            0
# 2          298438   0.36    5230            5079.0  0.67            0
# 3          282053   0.37    5554            5230.0  0.72            0
# 4          288446   0.39    6018            5554.0  0.78            0
#
#      genre  tony_noms  tony_awards
# 0  Mystery          1            0
# 1  Mystery          1            0
# 2  Mystery          1            0
# 3  Mystery          1            0
# 4  Mystery          1            0

# %%
df
# Out:
#            date                        show  type   theatre  previews  \
# 0    2017-05-21                        1984  Play    Hudson         4
# 1    2017-05-28                        1984  Play    Hudson         7
# 2    2017-06-04                        1984  Play    Hudson         8
# 3    2017-06-11                        1984  Play    Hudson         8
# 4    2017-06-18                        1984  Play    Hudson         8
# ...         ...                         ...   ...       ...       ...
# 8205 2015-01-25  YOU CAN'T TAKE IT WITH YOU  Play  Longacre         0
# 8206 2015-02-01  YOU CAN'T TAKE IT WITH YOU  Play  Longacre         0
# 8207 2015-02-08  YOU CAN'T TAKE IT WITH YOU  Play  Longacre         0
# 8208 2015-02-15  YOU CAN'T TAKE IT WITH YOU  Play  Longacre         0
# 8209 2015-02-22  YOU CAN'T TAKE IT WITH YOU  Play  Longacre         0
#
#       performances  grosses prev_week_gross  GG%GP  attend  prev_week_attend  \
# 0                0   212626               $   0.48    3378               NaN
# 1                0   298438          212626   0.45    5079            3378.0
# 2                0   282053          298438   0.36    5230            5079.0
# 3                0   288446          282053   0.37    5554            5230.0
# 4                0   301461          288446   0.39    6018            5554.0
# ...            ...      ...             ...    ...     ...               ...
# 8205             8   441995          445041   0.45    5613            5883.0
# 8206             8   354139          441995   0.36    4986            5613.0
# 8207             8   334244          354139   0.34    4507            4986.0
# 8208             8   412057          334244   0.42    5167            4507.0
# 8209             8   403767          412057   0.42    5574            5167.0
#
#       %cap  close_month    genre  tony_noms  tony_awards
# 0     0.87            0  Mystery          1            0
# 1     0.75            0  Mystery          1            0
# 2     0.67            0  Mystery          1            0
# 3     0.72            0  Mystery          1            0
# 4     0.78            0  Mystery          1            0
# ...    ...          ...      ...        ...          ...
# 8205  0.65            1   Comedy          0            0
# 8206  0.58            1   Comedy          0            0
# 8207  0.53            1   Comedy          0            0
# 8208  0.60            1   Comedy          0            0
# 8209  0.65            1   Comedy          0            0
#
# [8210 rows x 16 columns]

# %%
df['type'].nunique()
# Out:
# 3

# %%
df['type'].unique()
# Out:
# array(['Play', 'Musical', 'Special'], dtype=object)

# %%
print('----------------------------------------------------------')
print('The number of Broadway Shows in this dataset is:',df['show'].nunique())
# Out:
# ----------------------------------------------------------
# The number of Broadway Shows in this dataset is: 233

# %%
df['show'].unique()
# Out:
# array([1984, 'A CHRISTMAS CAROL 2019', "A SOLDIER'S PLAY",
#        "AIN'T TOO PROUD", 'A BRONX TALE THE MUSICAL',
#        'A DELICATE BALANCE 2014', "A DOLL'S HOUSE, PART 2",
#        "A GENTLEMAN'S GUIDE TO LOVE AND MURDER",
#        'A VIEW FROM THE BRIDGE 2015', 'AIRLINE HIGHWAY', 'ALADDIN',
#        'ALL MY SONS 2019', 'AMERICAN SON', 'AMERICAN UTOPIA',
#        'ALLEGIANCE', 'ALTON BROWN LIVE: EAT YOUR SCIENCE',
#        'AMAZING GRACE', 'AMÉLIE', 'AMERICAN PSYCHO', 'AN ACT OF GOD',
#        'AN ACT OF GOD 2016', 'AN AMERICAN IN PARIS', 'ANASTASIA',
#        'ANGELS IN AMERICA 2018', 'BANDSTAND', 'BARRY MANILOW',
#        'BE MORE CHILL', 'BEAUTIFUL', 'BEETLEJUICE', 'BETRAYAL 2019',
#        'BURN THIS 2019', 'BERNHARDT/HAMLET', 'BLACK TO THE FUTURE',
#        'BLACKBIRD', 'BRIGHT STAR', "CABARET '14", 'CAROUSEL 2018',
#        'CATS 2016', 'CELEBRITY AUTOBIOGRAPHY',
#        'CHARLIE AND THE CHOCOLATE FACTORY', 'CHICAGO', 'CHOIR BOY',
#        'CHILDREN OF A LESSER GOD 2018', 'CHINA DOLL', 'COME FROM AWAY',
#        'CRISS ANGEL', 'DAVE CHAPPELLE', 'CONSTELLATIONS', 'DAMES AT SEA',
#        'DEAR EVAN HANSEN', 'DERREN BROWN: SECRET',
#        'FRANKIE AND JOHNNY IN THE CLAIR DE LUNE 2019',
#        'FREESTYLE LOVE SUPREME', 'DISASTER!', 'DISGRACED',
#        'DOCTOR ZHIVAGO', 'ECLIPSED', 'ESCAPE TO MARGARITAVILLE',
#        'FALSETTOS 2016', 'FARINELLI AND THE KING',
#        'FIDDLER ON THE ROOF 2015', 'FINDING NEVERLAND',
#        'FISH IN THE DARK', 'FOOL FOR LOVE',
#        'FRANKIE VALLI AND THE FOUR SEASONS ON BROADWAY 2016',
#        'FROZEN 2018', 'GARY: A SEQUEL TO TITUS ANDRONICUS',
#        'GRAND HORIZONS', 'HADESTOWN', 'FULLY COMMITTED', 'FUN HOME',
#        "GETTIN' THE BAND BACK TOGETHER", 'GIGI', 'GROUNDHOG DAY',
#        'HAMILTON', 'HARRY CONNICK, JR. - A CELEBRATION OF COLE PORTER',
#        'HAND TO GOD',
#        'HARRY POTTER AND THE CURSED CHILD, PARTS ONE AND TWO',
#        'HILLARY AND CLINTON', 'INK', 'JAGGED LITTLE PILL',
#        'HEAD OVER HEELS', 'HEDWIG AND THE ANGRY INCH', 'HEISENBERG',
#        'HELLO, DOLLY! 2017', 'HOLIDAY INN', 'HOME FOR THE HOLIDAYS',
#        'HONEYMOON IN VEGAS', 'HUGHIE 2016', 'IF/THEN', 'IN TRANSIT',
#        'INDECENT', 'IT SHOULDA BEEN YOU', "IT'S ONLY A PLAY",
#        'JERSEY BOYS', 'JITNEY', 'JOHN LITHGOW: STORIES BY HEART', 'JUNK',
#        'KING CHARLES III', 'KING KONG', 'KING LEAR 2019', 'KINKY BOOTS',
#        'KISS ME, KATE 2019', 'KRISTIN CHENOWETH: FOR THE GIRLS',
#        'LINDA VISTA', 'LATIN HISTORY FOR MORONS',
#        'LES LIAISONS DANGEREUSES 2016', "LES MISÉRABLES '14",
#        'LIVING ON LOVE', 'LOBBY HERO',
#        "LONG DAY'S JOURNEY INTO NIGHT 2016",
#        'LORD OF THE DANCE: DANGEROUS GAMES', 'M. BUTTERFLY 2017',
#        'MAMMA MIA!', "MARVIN'S ROOM", 'MATILDA', 'MEAN GIRLS',
#        'MEL BROOKS', 'MORRISSEY', 'MOULIN ROUGE!', 'METEOR SHOWER',
#        'MISERY', 'MISS SAIGON 2017', 'MOTOWN THE MUSICAL',
#        'MOTOWN THE MUSICAL 2016', 'MY FAIR LADY 2018',
#        'MY LOVE LETTER TO BROADWAY',
#        'NATASHA, PIERRE & THE GREAT COMET OF 1812', 'NETWORK',
#        'OKLAHOMA! 2019', 'NOISES OFF 2016', 'OH, HELLO ON BROADWAY',
#        'OLD TIMES', 'ON THE TOWN 2014', 'ON THE TWENTIETH CENTURY',
#        'ON YOUR FEET!', 'ONCE ON THIS ISLAND 2017', 'OSLO',
#        "OUR MOTHER'S BRIEF AFFAIR", 'PARAMOUR',
#        'PENN & TELLER ON BROADWAY', 'PRESENT LAUGHTER 2017',
#        'PRETTY WOMAN: THE MUSICAL', 'REGINA SPEKTOR', 'SEA WALL/A LIFE',
#        "SLAVA'S SNOWSHOW 2019", 'SLAVE PLAY', 'PRINCE OF BROADWAY',
#        'ROCKTOPIA',
#        "RUBEN & CLAY'S FIRST ANNUAL CHRISTMAS CAROL FAMILY FUN PAGEANT SPECTACULAR REUNION SHOW",
#        'SAINT JOAN 2018', 'SCHOOL OF ROCK', 'SHE LOVES ME 2016',
#        'SHUFFLE ALONG', 'SIGNIFICANT OTHER',
#        'SIX DEGREES OF SEPARATION 2017', 'SKYLIGHT 2015',
#        'SOMETHING ROTTEN!', 'SPONGEBOB SQUAREPANTS',
#        'SPRING AWAKENING 2015', 'SPRINGSTEEN ON BROADWAY', 'SUMMER',
#        'SUNDAY IN THE PARK WITH GEORGE 2017', 'SUNSET BOULEVARD 2017',
#        'SWEAT', 'SYLVIA', 'THE AUDIENCE', "THE BAND'S VISIT",
#        'THE BOOK OF MORMON', 'THE BOYS IN THE BAND', 'THE CHER SHOW',
#        'THE CHERRY ORCHARD 2016', 'THE CHILDREN', 'THE COLOR PURPLE 2015',
#        'THE CRUCIBLE 2016',
#        'THE CURIOUS INCIDENT OF THE DOG IN THE NIGHT-TIME',
#        'THE ELEPHANT MAN 2014', 'THE ENCOUNTER', 'THE FATHER 2016',
#        'THE FERRYMAN', 'THE GREAT SOCIETY', 'THE HEIGHT OF THE STORM',
#        'THE ILLUSIONISTS - MAGIC OF THE HOLIDAYS 2019', 'THE INHERITANCE',
#        'THE LIGHTNING THIEF', 'THE FRONT PAGE 2016', 'THE GIN GAME 2015',
#        'THE GLASS MENAGERIE 2017', 'THE HEIDI CHRONICLES 2015',
#        'THE HUMANS', 'THE ICEMAN COMETH 2018',
#        'THE ILLUSIONISTS - LIVE ON BROADWAY',
#        'THE ILLUSIONISTS - MAGIC OF THE HOLIDAYS',
#        'THE ILLUSIONISTS - TURN OF THE CENTURY',
#        'THE ILLUSIONISTS - WITNESS THE IMPOSSIBLE', 'THE KING AND I 2015',
#        'THE LAST SHIP', 'THE LIFESPAN OF A FACT', 'THE LION KING',
#        'THE NEW ONE', 'THE LITTLE FOXES 2017', 'THE NAP',
#        'THE PARISIAN WOMAN', 'THE PHANTOM OF THE OPERA',
#        'THE PLAY THAT GOES WRONG', 'THE PRESENT', 'THE PRICE 2017',
#        'THE PROM', 'THE ROSE TATTOO 2019', 'THE SOUND INSIDE',
#        'TINA - THE TINA TURNER MUSICAL', 'THE RIVER',
#        'THE TEMPTATIONS AND THE FOUR TOPS ON BROADWAY',
#        'THE TERMS OF MY SURRENDER', 'THE VISIT 2015',
#        'THE WAVERLY GALLERY', 'THÉRÈSE RAQUIN', 'THREE TALL WOMEN',
#        'TIME AND THE CONWAYS', 'TO KILL A MOCKINGBIRD', 'TOOTSIE',
#        'TRUE WEST 2019', 'TORCH SONG', 'TRAVESTIES 2018',
#        'TUCK EVERLASTING', 'WAITRESS', 'WEST SIDE STORY 2020',
#        'WHAT THE CONSTITUTION MEANS TO ME', 'WAR PAINT', 'WICKED',
#        'YANNI', 'WOLF HALL PARTS ONE & TWO', "YOU CAN'T TAKE IT WITH YOU"],
#       dtype=object)

# %%
df.isna().sum()
# Out:
# date                  0
# show                  0
# type                  0
# theatre               0
# previews              0
# performances          0
# grosses               0
# prev_week_gross       0
# GG%GP                 0
# attend                0
# prev_week_attend    213
# %cap                  0
# close_month           0
# genre                 0
# tony_noms             0
# tony_awards           0
# dtype: int64

# %%
df['show'] = df['show'].str.capitalize()

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7978 entries, 21 to 8209
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              7978 non-null   datetime64[ns]
#  1   show              7978 non-null   object
#  2   type              7978 non-null   object
#  3   theatre           7978 non-null   object
#  4   previews          7978 non-null   int64
#  5   performances      7978 non-null   int64
#  6   grosses           7978 non-null   int64
#  7   prev_week_gross   7978 non-null   object
#  8   GG%GP             7978 non-null   float64
#  9   attend            7978 non-null   int64
#  10  prev_week_attend  7978 non-null   float64
#  11  %cap              7978 non-null   float64
#  12  close_month       7978 non-null   int64
#  13  genre             7978 non-null   object
#  14  tony_noms         7978 non-null   int64
#  15  tony_awards       7978 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#           previews  performances       grosses        GG%GP        attend  \
# count  7978.000000   7978.000000  7.978000e+03  7978.000000   7978.000000
# mean      0.500376      7.429556  9.756514e+05     0.736296   8512.940963
# std       1.830696      1.968312  5.829954e+05     0.248156   2827.493530
# min       0.000000      0.000000  4.849600e+04     0.030000   1384.000000
# 25%       0.000000      8.000000  5.825955e+05     0.540000   6474.250000
# 50%       0.000000      8.000000  8.381615e+05     0.710000   8107.000000
# 75%       0.000000      8.000000  1.209606e+06     0.930000  10483.750000
# max       8.000000     17.000000  4.041493e+06     1.700000  24305.000000
#
#        prev_week_attend         %cap  close_month    tony_noms  tony_awards
# count       7978.000000  7978.000000  7978.000000  7978.000000  7978.000000
# mean        8432.167837     0.870223     0.129732     6.666834     2.755076
# std         2889.371202     0.136111     0.336029     4.849554     3.325390
# min          500.000000     0.230000     0.000000     0.000000     0.000000
# 25%         6387.500000     0.780000     0.000000     2.000000     0.000000
# 50%         8060.500000     0.900000     0.000000     7.000000     1.000000
# 75%        10447.750000     0.990000     0.000000    10.000000     5.000000
# max        17517.000000     1.040000     1.000000    16.000000    11.000000

# %%
df.isna().sum()
# Out:
# date                0
# show                0
# type                0
# theatre             0
# previews            0
# performances        0
# grosses             0
# prev_week_gross     0
# GG%GP               0
# attend              0
# prev_week_attend    0
# %cap                0
# close_month         0
# genre               0
# tony_noms           0
# tony_awards         0
# dtype: int64

# %%
df = df.set_index('date')

# %%
df.head()
# Out:
#                               show  type theatre  previews  performances  \
# date
# 2019-11-17  A christmas carol 2019  Play  Lyceum         8             0
# 2019-11-24  A christmas carol 2019  Play  Lyceum         1             7
# 2019-12-01  A christmas carol 2019  Play  Lyceum         0             9
# 2019-12-08  A christmas carol 2019  Play  Lyceum         0             8
# 2019-12-15  A christmas carol 2019  Play  Lyceum         0             8
#
#             grosses prev_week_gross  GG%GP  attend  prev_week_attend  %cap  \
# date
# 2019-11-17   257525          106450   0.30    4194            1651.0  0.62
# 2019-11-24   384493          257525   0.45    5590            4194.0  0.82
# 2019-12-01   734745          384493   0.77    5988            5590.0  0.78
# 2019-12-08   757702          734745   0.90    6164            5988.0  0.91
# 2019-12-15   822983          757702   0.97    6619            6164.0  0.98
#
#             close_month     genre  tony_noms  tony_awards
# date
# 2019-11-17            0  Seasonal          5            3
# 2019-11-24            0  Seasonal          5            3
# 2019-12-01            0  Seasonal          5            3
# 2019-12-08            0  Seasonal          5            3
# 2019-12-15            0  Seasonal          5            3

# %% [markdown]
# # EDA

# %%
df.hist(figsize=(14,9))
# Out:
# array([[<AxesSubplot:title={'center':'previews'}>,
#         <AxesSubplot:title={'center':'performances'}>,
#         <AxesSubplot:title={'center':'grosses'}>],
#        [<AxesSubplot:title={'center':'GG%GP'}>,
#         <AxesSubplot:title={'center':'attend'}>,
#         <AxesSubplot:title={'center':'prev_week_attend'}>],
#        [<AxesSubplot:title={'center':'%cap'}>,
#         <AxesSubplot:title={'center':'close_month'}>,
#         <AxesSubplot:title={'center':'tony_noms'}>],
#        [<AxesSubplot:title={'center':'tony_awards'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ### Hamilton Data

# %%
df_hamilton = df[df.show.str.contains('Hamilton')]

# %%
df_hamilton.head()
# Out:
#                 show     type          theatre  previews  performances  \
# date
# 2015-07-26  Hamilton  Musical  Richard Rodgers         7             0
# 2015-08-02  Hamilton  Musical  Richard Rodgers         8             0
# 2015-08-09  Hamilton  Musical  Richard Rodgers         4             4
# 2015-08-16  Hamilton  Musical  Richard Rodgers         0             8
# 2015-08-23  Hamilton  Musical  Richard Rodgers         0             8
#
#             grosses prev_week_gross  GG%GP  attend  prev_week_attend  %cap  \
# date
# 2015-07-26  1302511         1288436   1.12    9290            9273.0  1.00
# 2015-08-02  1490816         1302511   1.12   10619            9290.0  1.00
# 2015-08-09  1255163         1490816   0.94   10638           10619.0  1.01
# 2015-08-16  1459314         1255163   1.09   10706           10638.0  1.01
# 2015-08-23  1456753         1459314   1.09   10708           10706.0  1.01
#
#             close_month  genre  tony_noms  tony_awards
# date
# 2015-07-26            0  Drama         16           11
# 2015-08-02            0  Drama         16           11
# 2015-08-09            0  Drama         16           11
# 2015-08-16            0  Drama         16           11
# 2015-08-23            0  Drama         16           11

# %% [markdown]
# ### Beetlejuice Data

# %%
df_beetlejuice = df[df.show.str.contains('Beetlejuice')]

# %%
df_beetlejuice.head()
# Out:
#                    show     type        theatre  previews  performances  \
# date
# 2019-04-07  Beetlejuice  Musical  Winter Garden         7             0
# 2019-04-14  Beetlejuice  Musical  Winter Garden         7             0
# 2019-04-21  Beetlejuice  Musical  Winter Garden         7             0
# 2019-04-28  Beetlejuice  Musical  Winter Garden         4             4
# 2019-05-05  Beetlejuice  Musical  Winter Garden         0             8
#
#             grosses prev_week_gross  GG%GP  attend  prev_week_attend  %cap  \
# date
# 2019-04-07   765711          332008   0.65    9903            2700.0  0.95
# 2019-04-14   686456          765711   0.59    9506            9903.0  0.91
# 2019-04-21   797929          686456   0.68   10375            9506.0  0.99
# 2019-04-28   834395          797929   0.63   11977           10375.0  1.00
# 2019-05-05   818904          834395   0.60   10086           11977.0  0.84
#
#             close_month   genre  tony_noms  tony_awards
# date
# 2019-04-07            0  Comedy          8            0
# 2019-04-14            0  Comedy          8            0
# 2019-04-21            0  Comedy          8            0
# 2019-04-28            0  Comedy          8            0
# 2019-05-05            0  Comedy          8            0

# %% [markdown]
# ### Anastasia

# %%
df_anastasia = df[df.show.str.contains('Anastasia')]

# %%
df_anastasia
# Out:
#                  show     type     theatre  previews  performances  grosses  \
# date
# 2017-04-02  Anastasia  Musical  Broadhurst         7             0   971783
# 2017-04-09  Anastasia  Musical  Broadhurst         7             0   922021
# 2017-04-16  Anastasia  Musical  Broadhurst         8             0  1207938
# 2017-04-23  Anastasia  Musical  Broadhurst         8             0   989231
# 2017-04-30  Anastasia  Musical  Broadhurst         0             8   882853
# ...               ...      ...         ...       ...           ...      ...
# 2019-03-03  Anastasia  Musical  Broadhurst         0             8   557480
# 2019-03-10  Anastasia  Musical  Broadhurst         0             8   681938
# 2019-03-17  Anastasia  Musical  Broadhurst         0             8   837803
# 2019-03-24  Anastasia  Musical  Broadhurst         0             8   920068
# 2019-03-31  Anastasia  Musical  Broadhurst         0             8  1012316
#
#            prev_week_gross  GG%GP  attend  prev_week_attend  %cap  \
# date
# 2017-04-02          629307   0.97    8012            4572.0  1.00
# 2017-04-09          971783   0.92    7847            8012.0  0.98
# 2017-04-16          922021   1.05    9196            7847.0  1.01
# 2017-04-23         1207938   0.86    9061            9196.0  0.99
# 2017-04-30          989231   0.77    9030            9061.0  0.99
# ...                    ...    ...     ...               ...   ...
# 2019-03-03          638470   0.51    7020            7576.0  0.77
# 2019-03-10          557480   0.62    7499            7020.0  0.82
# 2019-03-17          681938   0.77    9055            7499.0  0.99
# 2019-03-24          837803   0.84    8948            9055.0  0.98
# 2019-03-31          920068   0.93    8744            8948.0  0.96
#
#             close_month    genre  tony_noms  tony_awards
# date
# 2017-04-02            0  Classic          2            0
# 2017-04-09            0  Classic          2            0
# 2017-04-16            0  Classic          2            0
# 2017-04-23            0  Classic          2            0
# 2017-04-30            0  Classic          2            0
# ...                 ...      ...        ...          ...
# 2019-03-03            1  Classic          2            0
# 2019-03-10            1  Classic          2            0
# 2019-03-17            1  Classic          2            0
# 2019-03-24            1  Classic          2            0
# 2019-03-31            0  Classic          2            0
#
# [104 rows x 15 columns]

# %% [markdown]
# ## Time Plots

# %%
import plotly.express as px

# %% [markdown]
# ### % Capacity Filled

# %% [markdown]
# **HAMILTON**

# %%
px.line(df_hamilton, x=df_hamilton.index, y='%cap')
# Out:
# <div>                            <div id="a2f1257e-1340-4679-a037-e4b321d5effd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2f1257e-1340-4679-a037-e4b321d5effd")) {                    Plotly.newPlot(                        "a2f1257e-1340-4679-a037-e4b321d5effd",                        [{"hovertemplate": "date=%{x}<br>%cap=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2015-07-26T00:00:00", "2015-08-02T00:00:00", "2015-08-09T00:00:00", "2015-08-16T00:00:00", "2015-08-23T00:00:00", "2015-08-30T00:00:00", "2015-09-06T00:00:00", "2015-09-13T00:00:00", "2015-09-20T00:00:00", "2015-09-27T00:00:00", "2015-10-04T00:00:00", "2015-10-11T00:00:00", "2015-10-18T00:00:00", "2015-10-25T00:00:00", "2015-11-01T00:00:00", "2015-11-08T00:00:00", "2015-11-15T00:00:00", "2015-11-22T00:00:00", "2015-11-29T00:00:00", "2015-12-06T00:00:00", "2015-12-13T00:00:00", "2015-12-20T00:00:00", "2015-12-27T00:00:00", "2016-01-03T00:00:00", "2016-01-10T00:00:00", "2016-01-17T00:00:00", "2016-01-24T00:00:00", "2016-01-31T00:00:00", "2016-02-07T00:00:00", "2016-02-14T00:00:00", "2016-02-21T00:00:00", "2016-02-28T00:00:00", "2016-03-06T00:00:00", "2016-03-13T00:00:00", "2016-03-20T00:00:00", "2016-03-27T00:00:00", "2016-04-03T00:00:00", "2016-04-10T00:00:00", "2016-04-17T00:00:00", "2016-04-24T00:00:00", "2016-05-01T00:00:00", "2016-05-08T00:00:00", "2016-05-15T00:00:00", "2016-05-22T00:00:00", "2016-05-29T00:00:00", "2016-06-05T00:00:00", "2016-06-12T00:00:00", "2016-06-19T00:00:00", "2016-06-26T00:00:00", "2016-07-03T00:00:00", "2016-07-10T00:00:00", "2016-07-17T00:00:00", "2016-07-24T00:00:00", "2016-07-31T00:00:00", "2016-08-07T00:00:00", "2016-08-14T00:00:00", "2016-08-21T00:00:00", "2016-08-28T00:00:00", "2016-09-04T00:00:00", "2016-09-11T00:00:00", "2016-09-18T00:00:00", "2016-09-25T00:00:00", "2016-10-02T00:00:00", "2016-10-09T00:00:00", "2016-10-16T00:00:00", "2016-10-23T00:00:00", "2016-10-30T00:00:00", "2016-11-06T00:00:00", "2016-11-13T00:00:00", "2016-11-20T00:00:00", "2016-11-27T00:00:00", "2016-12-04T00:00:00", "2016-12-11T00:00:00", "2016-12-18T00:00:00", "2016-12-25T00:00:
#                        show     type   theatre  previews  performances  \
# date
# 2019-03-31  Ain't too proud  Musical  Imperial         0             8
# 2019-03-10  Ain't too proud  Musical  Imperial         7             0
# 2019-03-17  Ain't too proud  Musical  Imperial         7             0
# 2019-03-24  Ain't too proud  Musical  Imperial         4             4
# 2019-04-07  Ain't too proud  Musical  Imperial         0             8
#
#             grosses prev_week_gross  GG%GP  attend  prev_week_attend  %cap  \
# date
# 2019-03-31  1330046         1102218   0.92   11176           11378.0  0.98
# 2019-03-10   872597          472627   0.70    9233            4164.0  0.93
# 2019-03-17   949781          872597   0.76    9810            9233.0  0.98
# 2019-03-24  1102218          949781   0.76   11378            9810.0  1.00
# 2019-04-07  1337083         1330046   0.93   10943           11176.0  0.96
#
#             close_month    genre  tony_noms  tony_awards
# date
# 2019-03-31            0  Jukebox         12            1
# 2019-03-10            0  Jukebox         12            1
# 2019-03-17            0  Jukebox         12            1
# 2019-03-24            0  Jukebox         12            1
# 2019-04-07            0  Jukebox         12            1

# %%
df_musical.show.nunique()
# Out:
# 94

# %%
fig, ax = pyplot.subplots(figsize=(30,14))

g = sns.boxplot(data=df_musical, x='show', y='grosses', palette='crest')
g.set_xticklabels(g.get_xticklabels(), rotation=45, ha='right')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_play = df[df.type.str.contains('Play')]

# %%
df_play.head()
# Out:
#                               show  type theatre  previews  performances  \
# date
# 2019-11-17  A christmas carol 2019  Play  Lyceum         8             0
# 2019-11-24  A christmas carol 2019  Play  Lyceum         1             7
# 2019-12-01  A christmas carol 2019  Play  Lyceum         0             9
# 2019-12-08  A christmas carol 2019  Play  Lyceum         0             8
# 2019-12-15  A christmas carol 2019  Play  Lyceum         0             8
#
#             grosses prev_week_gross  GG%GP  attend  prev_week_attend  %cap  \
# date
# 2019-11-17   257525          106450   0.30    4194            1651.0  0.62
# 2019-11-24   384493          257525   0.45    5590            4194.0  0.82
# 2019-12-01   734745          384493   0.77    5988            5590.0  0.78
# 2019-12-08   757702          734745   0.90    6164            5988.0  0.91
# 2019-12-15   822983          757702   0.97    6619            6164.0  0.98
#
#             close_month     genre  tony_noms  tony_awards
# date
# 2019-11-17            0  Seasonal          5            3
# 2019-11-24            0  Seasonal          5            3
# 2019-12-01            0  Seasonal          5            3
# 2019-12-08            0  Seasonal          5            3
# 2019-12-15            0  Seasonal          5            3

# %%
fig, ax = pyplot.subplots(figsize=(30,14))

g = sns.boxplot(data=df_play, x='show', y='grosses', palette='crest')
g.set_xticklabels(g.get_xticklabels(), rotation=45, ha='right')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = pyplot.subplots(figsize=(20,14))
sns.lineplot(data=df, x='%cap', y='GG%GP')
# Out:
# <AxesSubplot:xlabel='%cap', ylabel='GG%GP'>

# %% [markdown]
# # Baseline Modeling

# %%
df = df[~df.type.str.contains("Special")]

# %%
df.shape
# Out:
# (7840, 15)

# %% [markdown]
# ## One Hote Encoding

# %%
df = pd.get_dummies(df, columns = ['show', 'type', 'theatre', 'genre'], drop_first = True)

# %%
df.shape
# Out:
# (7840, 262)

# %% [markdown]
# **CREATE VARIABLES**

# %%
X = df.drop('close_month', axis = 1)
y = df['close_month']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %% [markdown]
# # Models

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC
svcls = SVC(kernel='rbf', C=1, gamma = 2**-5)
svc = svcls.fit(X_train, y_train)

# %%
y_pred_svc = svcls.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      1691
#            1       0.00      0.00      0.00       269
#
#     accuracy                           0.86      1960
#    macro avg       0.43      0.50      0.46      1960
# weighted avg       0.74      0.86      0.80      1960
# /Users/andrewozbun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
from sklearn.metrics import confusion_matrix

cnf_matrix = confusion_matrix(y_test, y_pred_svc)
print('Confusion Matrix:\n', cnf_matrix)
# Out:
# Confusion Matrix:
#  [[1691    0]
#  [ 269    0]]

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
plot_confusion_matrix(svc, X_test, y_test, cmap=plt.cm.Blues, display_labels = ['Do not Close', 'Close'])
plt.grid(False)
plt.show()

# %% [markdown]
# ### Class Imbalance

# %%
count_classes = pd.value_counts(df['close_month'], sort = True)
count_classes.plot(kind = 'bar', rot=0)

plt.title("Open and Closing Class Distribution")
plt.xticks((0,1), ('Open', 'Closing'))
plt.xlabel("Class")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ### SMOTE

# %%
from imblearn.over_sampling import SMOTE 

sm = SMOTE(random_state=42)

X_sm, y_sm = sm.fit_resample(X, y)


##finding shortcuts for printing clean data results
print(f'''Shape of X before SMOTE: {X.shape}
Shape of X after SMOTE: {X_sm.shape}''')

print('\nBalance of positive and negative classes (Percentage):')
y_sm.value_counts(normalize=True) * 100
# Out:
# Shape of X before SMOTE: (7840, 261)
# Shape of X after SMOTE: (13622, 261)
#
# Balance of positive and negative classes (Percentage):
# 1    50.0
# 0    50.0
# Name: close_month, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_sm, y_sm, test_size=0.25, random_state=42)

# %% [markdown]
# ### SVM Rerun

# %%
svc = svcls.fit(X_train, y_train)
y_pred_svc = svcls.predict(X_test)

# %%
cnf_matrix = confusion_matrix(y_test, y_pred_svc)
print('Confusion Matrix:\n', cnf_matrix)
# Out:
# Confusion Matrix:
#  [[   0 1745]
#  [   0 1661]]

# %%
plot_confusion_matrix(svc, X_test, y_test, cmap=plt.cm.Blues, display_labels = ['Do Not Close', 'Close'])
plt.grid(False)
plt.show()

# %%
print(classification_report(y_test, y_pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1745
#            1       0.49      1.00      0.66      1661
#
#     accuracy                           0.49      3406
#    macro avg       0.24      0.50      0.33      3406
# weighted avg       0.24      0.49      0.32      3406
# /Users/andrewozbun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# ## Random Forest

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=100, max_depth=32,  
                             max_leaf_nodes=40)
rf_clf = clf.fit(X_train,y_train)

y_pred_rf = clf.predict(X_test)

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90      1745
#            1       0.90      0.89      0.90      1661
#
#     accuracy                           0.90      3406
#    macro avg       0.90      0.90      0.90      3406
# weighted avg       0.90      0.90      0.90      3406

# %%
plot_confusion_matrix(rf_clf, X_test, y_test,  cmap=plt.cm.Blues, display_labels = ['Do Not Close', 'Close'] )
plt.title('Confusion Matrix for Random Forest')
plt.grid(False)
plt.show()

# %%
## Initial overfitting in this plot
from sklearn import tree
plt.figure(figsize = (15,10))
tree.plot_tree(rf_clf.estimators_[2], rounded = True, 
               filled = True, 
               class_names = ['Close', 'Do Note Close'], 
               feature_names = X.columns)
plt.show()
